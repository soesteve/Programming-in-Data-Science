# %% [markdown]
# # Estructuras de datos básicas

# %% [markdown]
# Las estructuras de datos permiten almacenar y organizar información. Python incluye cuatro estructuras fundamentales:
#
# - Listas (list)
#
# - Tuplas (tuple)
#
# - Conjuntos (set)
#
# - Diccionarios (dict)

# %% [markdown]
# ## Listas (list)
#
# Las listas son colecciones ordenadas y modificables. Pueden contener elementos de distintos tipos (característica no común con otros lenguajes de programación).

# %%
# Crear una lista
frutas = ["manzana", "pera", "plátano"]

print(frutas)
# Out:
# ['manzana', 'pera', 'plátano']

# %% [markdown]
# ### Acceso a los elementos de una lista
#
# Se acceden a los elementos mediante el operador `[ ]`. Los elementos de una lista están indexados y los índices comienzan en 0.

# %%
print(frutas[0])      # Primer elemento
print(frutas[-1])     # Último elemento
# Out:
# manzana
# plátano

# %% [markdown]
# ### Modificar una lista
# Los elementos de la lista se modifican usando la asignación (=).

# %%
frutas[1] = "uva"
print(frutas)
# Out:
# ['manzana', 'uva', 'plátano']

# %% [markdown]
# ### Operaciones frecuentes

# %%
frutas.append("kiwi")      # Añadir al final
print(frutas)
frutas.insert(1, "fresa")  # Insertar en una posición
print(frutas)
frutas.remove("uva")       # Eliminar por valor
print(frutas)
frutas.pop()      # Eliminar el último
print(frutas)
# Out:
# ['manzana', 'uva', 'plátano', 'kiwi']
# ['manzana', 'fresa', 'uva', 'plátano', 'kiwi']
# ['manzana', 'fresa', 'plátano', 'kiwi']
# ['manzana', 'fresa', 'plátano']

# %%
len(frutas)    # Longitud
# Out:
# 3

# %% [markdown]
# ## Tuplas (tuple)
#
# Las tuplas son ordenadas pero inmutables. Una vez creadas, no pueden modificarse.
# Se suelen usar para coordenadas, fechas fijas...

# %%
coordenada = (10, 20)
print(coordenada)
# Out:
# (10, 20)

# %% [markdown]
# ### Acceso

# %%
print(coordenada[0])
# Out:
# 10

# %% [markdown]
# ### Desempaquetado

# %%
x, y = coordenada
print(x, y)
# Out:
# 10 20

# %% [markdown]
# ## Conjuntos (set)
#
# Los conjuntos almacenan elementos sin orden y sin duplicados.

# %%
numeros = {1, 2, 3, 3, 4}
print(numeros)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# Las operaciones disponibles son:

# %%
numeros.add(5)     # Añade
print(numeros)
numeros.remove(2)  # Elimina
print(numeros)

print('---')

A = {2,4,6}
B = {3,4,5}

print(A | B)   # Unión
print(A & B)   # Intersección
print(A - B)   # Diferencia
# Out:
# {1, 2, 3, 4, 5}
# {1, 3, 4, 5}
# ---
# {2, 3, 4, 5, 6}
# {4}
# {2, 6}

# %% [markdown]
# ## Diccionarios (dict)
#
# Los diccionarios almacenan información mediante pares clave-valor. La clave es única.

# %%
persona = {
    "nombre": "Sonia",
    "edad": 25,
    "ciudad": "Madrid"
}

print(persona)
# Out:
# {'nombre': 'Sonia', 'edad': 25, 'ciudad': 'Madrid'}

# %% [markdown]
# Para acceder a los valores del diccionario usamos `dicc[calve]`

# %%
print(persona["nombre"])
print(persona["edad"])
# Out:
# Sonia
# 25

# %% [markdown]
# Podemos insertar/modificar los valores de un diccionario, las claves no.

# %%
persona["edad"] = 26
persona["profesion"] = "Matemática"
print(persona)
# Out:
# {'nombre': 'Sonia', 'edad': 26, 'ciudad': 'Madrid', 'profesion': 'Matemática'}

# %% [markdown]
# Podemos eliminar una entrada o fila

# %%
del persona['ciudad']

# %% [markdown]
# # Comparación de las estructuras
#
# |Estructura|Ordenada|Modificable|Duplicados|
# |----------|:--------:|:-----------:|:----------:|
# |Lista|Sí|Sí|Sí|
# |Tupla|Sí|No|Sí|
# |Conjunto|No|Sí|No|
# |Diccionario|Sí|Sí|Claves únicas|

# %% [markdown]
# # Referencias
#
# * [Tutorial de Python. Por Guido Van Rossum](http://docs.python.org.ar/tutorial/pdfs/TutorialPython3.pdf)
# * [Guía de estilo de código Python](https://www.python.org/dev/peps/pep-0008/)
# * [Big Data. Análisis de datos con Python. Sarasa Cabezuelo, Antonio; García Ruiz, Yolanda Aditorial Garceta. ISBN: 978-84-1622-883-6](http://www.garceta.es/libro.php?ISBN=978-84-1622-883-6)
