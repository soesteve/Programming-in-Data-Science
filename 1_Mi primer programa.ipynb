# %%
# Mi primer Notebook

# %%
print("Hola mundo, soy Sonia")
# Out:
# Hola mundo, soy Sonia

# %% [markdown]
# # Título 1

# %%
# Título 2

# %%
# Título 3

# %%
# Título 4

# %%
# Título 5

# %% [markdown]
# La instrucción *print* imprime lo que hay entre comillas: `print("Hola")`.

# %% [markdown]
# Veamos el siguiente código
# ```python
# for i in range(5):
#     print(i)
# ```

# %% [markdown]
# Lista con viñetas
# - 1
# - 2
# - 3
#
# Lista numerada
# 1. A
# 2. B
# 3. C

# %% [markdown]
# 1. sdf
# 2. ese
# 3. ere
# 3.1. sf
# 3.2. ertg

# %% [markdown]
# > Markdown es muy fácil de aprender.

# %% [markdown]
# | Nombre | Edad |
# |--------|------|
# | Ana | 20 |
# | Sonia | 25 |

# %% [raw]
# | Producto | Precio | Stock |
# |:---------|--------:|:-----:|
# | Lápiz    | 1,20   | Sí |
# | Cuaderno | 3,50   | No |

# %% [raw]
# Esta es una prueba de salto <br> de línea y de enlace [Abrir](https://sites.google.com/ucm.es/prof-sonia-estvez-martn/biograf%C3%ADa)
